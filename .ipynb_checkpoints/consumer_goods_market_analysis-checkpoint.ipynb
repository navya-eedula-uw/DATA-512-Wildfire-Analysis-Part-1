# %% [markdown]
# # Python Libraries and Installations
# 1. **`pandas`** *(Needs Installation)*: For data manipulation and analysis, especially handling tabular data with DataFrames.
#    - Installation:
#      ```
#      pip install pandas
#      ```
# 2. **`os`** *(Inbuilt)*: To interact with the operating system, such as reading and writing files or accessing environment variables.
# 3. **`plotly.graph_objects`** and **`plotly.subplots`** *(Needs Installation)*: For creating interactive visualizations and plotting diagnostic plots.
#    - Installation:
#      ```
#      pip install plotly
#      ```
# 4. **`seaborn`** *(Needs Installation)*:A statistical data visualization library built on top of `matplotlib`. It simplifies creating visually appealing plots.
#    - Installation:
#      ```
#      pip install seaborn
#      ```
#
# 5. **`matplotlib.pyplot`** *(Inbuilt in `matplotlib`, Needs Installation)*: A versatile library for static, animated, and interactive visualizations.
#    - Installation:
#      ```
#      pip install matplotlib
#      ```
#
# 6. **`scipy.stats`** *(Inbuilt in `scipy`, Needs Installation)*: Contains statistical functions and distributions.
#    - Installation:
#      ```
#      pip install scipy
#      ```
#
# 7. **`sklearn.preprocessing.MinMaxScaler`** *(Inbuilt in `scikit-learn`, Needs Installation)*: Normalizes the data within a specific range (e.g., 0 to 1) for machine learning models.
#    - Installation:
#      ```
#      pip install scikit-learn
#      ```
#
# 8. **`statsmodels.tsa.statespace.SARIMAX`** *(Inbuilt in `statsmodels`, Needs Installation)*: Implements Seasonal AutoRegressive Integrated Moving Average with eXogenous variables (SARIMAX) for time series modeling.
#    - Installation:
#      ```
#      pip install statsmodels
#      ```
#
# 9. **`sklearn.linear_model.LinearRegression`** *(Inbuilt in `scikit-learn`, Needs Installation)*: Fits a linear regression model for predictive tasks.
#    - Installation:
#      ```
#      pip install scikit-learn
#      ```
# 10. **`numpy`** *(Needs Installation)*: A fundamental package for numerical computing in Python. It provides support for multi-dimensional arrays, matrices, and a vast collection of mathematical functions to perform operations on these arrays efficiently.
#    - Installation:
#      ```
#      pip install numpy
#      ```

# %%
# Importing necessary libraries
import pandas as pd  # For data manipulation and handling tabular datasets
import numpy as np 
import os  # For interacting with the operating system

# Visualization libraries
import plotly.graph_objects as go  # For creating interactive visualizations
from plotly.subplots import make_subplots  # For creating subplots in Plotly
import seaborn as sns  # Statistical visualization library
import matplotlib.pyplot as plt  # For creating static plots

# Statistical and preprocessing tools
from scipy import stats  # For statistical operations like normality tests
from sklearn.preprocessing import MinMaxScaler  # For normalizing data
from sklearn.linear_model import LinearRegression # For building a Linear Regression Model

# Time-series modeling
from statsmodels.tsa.statespace.sarimax import SARIMAX  # For SARIMA modeling of time series

# %% [markdown]
# # Data Loading
#
# This code is used to load data from several CSV files related to into a format that can be analyzed. It starts by defining the folder where the files are stored and then reads each file into a table-like structure. After loading the data, it checks the contents of each table by showing details like the column names, the type of data in each column, and whether there are any missing values. This step helps ensure that the data is properly loaded and ready for further analysis.

# %%
# Define the folder path where the CSV files are stored
folder_path = "economy_data/"

# Load the "annual_consumer_price_index" data into a DataFrame from the specified folder
annual_consumer_price_index = pd.read_csv(os.path.join(folder_path, "annual_consumer_price_index.csv"))

# Load the "monthly_market_hotness_ranking" data into another DataFrame from the same folder
monthly_market_hotness_ranking = pd.read_csv(os.path.join(folder_path, "monthly_market_hotness_ranking.csv"))

# Display the structure and summary information of the "annual_consumer_price_index" DataFrame
print("Annual Consumer Price Index:")
print(annual_consumer_price_index.info(), "\n")

# Display the structure and summary information of the "monthly_market_hotness_ranking" DataFrame
print("Monthly Market Hotness Ranking:")
print(monthly_market_hotness_ranking.info(), "\n")
# Out:
# Annual Consumer Price Index:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DATE                         40 non-null     object
#  1   annual_consumer_price_index  40 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 772.0+ bytes
# None
#
# Monthly Market Hotness Ranking:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   DATE                            87 non-null     object
#  1   monthly_market_hotness_ranking  87 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.5+ KB
# None

# %% [markdown]
# This code reads data from a file that contains predictions related to smoke levels and processes it for further analysis. It starts by selecting only the relevant columns (`Year` and `Predicted_Value`) from the file and then renames these columns to make them more understandable. After this, it ensures the year values are stored as whole numbers to avoid formatting issues. Finally, it displays the first few rows of the data to confirm everything is loaded and formatted correctly. This process prepares the data for use in models or visualizations.

# %%
# Load the smoke estimates and predictions data from a CSV file, selecting only the 'Year' and 'Predicted_Value' columns
smoke_estimate_data = pd.read_csv("smoke_estimates_and_predictions.csv", usecols=["Year", "Predicted_Value"])

# Rename the columns for clarity and consistency
smoke_estimate_data.columns = ["Year", "Forecasted_Smoke_Estimate"]

# Convert the 'Year' column to integers to ensure proper data formatting
smoke_estimate_data['Year'] = smoke_estimate_data['Year'].astype(int)

# Display the first few rows of the processed data
smoke_estimate_data.head()
# Out:
#    Year  Forecasted_Smoke_Estimate
# 0  1964                   0.210585
# 1  1965                  -0.016844
# 2  1966                   0.084954
# 3  1967                  -0.024667
# 4  1968                  -0.024259

# %% [markdown]
# # Exploratory Data Analysis (EDA): Visualizing Smoke Estimate Data, Market Data, and Their Correlations
#
# This section focuses on visualizing the smoke estimate data and housing data, examining how they correlate, and identifying any noticeable trends. The goal is to understand the relationship between these datasets and uncover patterns that can inform further analysis.
#
# This code creates an interactive line graph using Plotly, displaying the forecasted smoke estimates over time. It first creates a figure and adds a line trace that plots the 'Year' on the x-axis and 'Forecasted_Smoke_Estimate' on the y-axis, with both lines and markers representing the data points. The layout of the plot is customized with titles for the axes and the plot itself, as well as setting the plot dimensions. Gridlines are added to make the graph easier to read. Additionally, a range slider and selector are included for zooming and focusing on different time periods, allowing users to view data from the last 10, 20, or 50 years, or all available data. Finally, the plot is displayed. This makes the visualization more user-friendly and interactive.

# %%
import plotly.graph_objects as go

# Create the figure
fig = go.Figure()

# Add the line trace
fig.add_trace(go.Scatter(
    x=smoke_estimate_data['Year'],
    y=smoke_estimate_data['Forecasted_Smoke_Estimate'],
    mode='lines+markers',
    name='Forecasted_Smoke_Estimate'
))

# Customize the layout
fig.update_layout(
    title='Line Graph of Forecasted_Smoke_Estimate',
    xaxis_title='Year',
    yaxis_title='Values',
    width=1400,
    height=600,
    showlegend=True
)

# Add gridlines
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='lightgray')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='lightgray')

# Add range slider and selector
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=10, label="10y", step="year", stepmode="backward"),
            dict(count=20, label="20y", step="year", stepmode="backward"),
            dict(count=50, label="50y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="c0d6c95f-d9de-42d7-b7aa-90a5c03e0273" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0d6c95f-d9de-42d7-b7aa-90a5c03e0273")) {                    Plotly.newPlot(                        "c0d6c95f-d9de-42d7-b7aa-90a5c03e0273",                        [{"mode":"lines+markers","name":"Forecasted_Smoke_Estimate","x":[1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025,2026,2027,2028,2029,2030,2031,2032,2033,2034,2035,2036,2037,2038,2039,2040,2041,2042,2043,2044,2045,2046,2047,2048,2049,2050],"y":[0.210585413557422,-0.0168441579466051,0.0849540542175494,-0.0246668985226365,-0.0242594384094879,0.0184760876063203,0.0310125471630703,0.1023581894725048,-0.0104360513706733,0.0405936904745862,0.069804999407546,0.0422361078170012,0.0375173210131281,0.0321704558312164,0.0401944684372902,0.0825979809998621,0.0822374059221787,0.1532369711708055,-0.0013363864964517,0.1153836883742248,0.0843553788538718,0.177009825223032,0.1672106443206786,0.2560391799975414,0.3743633772849258,0.2152056001406832,0.1772764416659127,0.1493497040632282,0.1439937934735576,0.0745105095300927,0.3026763866748551,0.2670958141277709,0.3487976822678417,0.1261921128702496,0.2101470617920775,0.3079004531357349,0.5279762544057272,0.3782374555026742,0.3743192299284111,0.6721453727705017,0.292491191599214,0.4796405611845292,0.6199966714155433,0.5220621175221289,0.4907842389847794,0.6168552730591194,0.6187456264192346,0.9890954326304472,0.8960040482938249,0.5287209993514163,0.489052400384572,0.5724276870580642,0.7978399728403258,0.8970219553248601,0.7940382532603493,0.77307698057365,1.005953720274388,0.524491209574516,0.5390815575136723,0.5536719054528272,0.568262253391989,0.5828526013311421,0.5974429492702978,0.6120332972094598,0.6266236451486128,0.6412139930877689,0.65580434102693,0.6703946889660858,0.6849850369052397,0.6995753848444006,0.7141657327835564,0.7287560807227114,0.7433464286618714,0.7579367766010268,0.7725271245401826,0.7871174724793424,0.8017078204184975,0.8162981683576593,0.8308885162968143,0.8454788642359683,0.8600692121751301,0.8746595601142853,0.8892499080534413,0.9038402559926002,0.918430603931756,0.933020951870912,0.947611299810071],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{ ...

# %% [markdown]
# The forecasted smoke estimate shows an overall upward trend from 2016 to 2020, with a notable peak in 2020 reaching nearly 1.0 on the normalized scale. According to an article titled "[Wildfire Risk and the Residential Housing
# Market: A Spatial Hedonic Analysis](https://ulife.vpul.upenn.edu/dolphin/ues/pje/content/Rossi.pdf)" by the University of Pennsylvania, this peak coincides with Colorado's worst wildfire season on record, including the Cameron Peak Fire which burned 208,913 acres. After 2020, the smoke estimate declined and stabilized around 0.55, suggesting a temporary improvement in air quality conditions but maintaining levels higher than pre-2020 periods.
#
# The below code defines a set of datasets in a dictionary, with each dataset being visualized in its own plot. The plots show how the data changes over time by plotting the values against the date. For each dataset, the plot includes a line graph with markers, allowing the user to visually track changes over time. The layout and styling of each plot are customized to improve readability, and interactive features like a range slider and time selectors are added so that the user can zoom in on specific time periods (e.g., 1 month, 1 year). Each plot is displayed to the user one by one.

# %%
# List of DataFrames
dataframes = {
    "annual_consumer_price_index": annual_consumer_price_index,
    "monthly_market_hotness_ranking": monthly_market_hotness_ranking,
}

# Visualize each DataFrame
for name, df in dataframes.items():
    fig = go.Figure()
    
    fig.add_trace(go.Scatter(
        x=df['DATE'],
        y=df.iloc[:, 1],
        mode='lines+markers',
        name=name
    ))
    
    fig.update_layout(
        title=f"{name.capitalize()} Over Time",
        xaxis_title="Date",
        yaxis_title=name,
        height=600,
        width=1400,
        showlegend=True
    )
    
    fig.update_xaxes(
        rangeslider_visible=True,
        rangeselector=dict(
            buttons=list([
                dict(count=1, label="1m", step="month", stepmode="backward"),
                dict(count=6, label="6m", step="month", stepmode="backward"),
                dict(count=1, label="1y", step="year", stepmode="backward"),
                dict(count=5, label="5y", step="year", stepmode="backward"),
                dict(step="all")
            ])
        )
    )
    
    fig.show()
# Out:
# <div>                            <div id="cbbb7ed6-caf6-4b1f-b39c-083db8974fc7" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbbb7ed6-caf6-4b1f-b39c-083db8974fc7")) {                    Plotly.newPlot(                        "cbbb7ed6-caf6-4b1f-b39c-083db8974fc7",                        [{"mode":"lines+markers","name":"annual_consumer_price_index","x":["1984-01-01","1985-01-01","1986-01-01","1987-01-01","1988-01-01","1989-01-01","1990-01-01","1991-01-01","1992-01-01","1993-01-01","1994-01-01","1995-01-01","1996-01-01","1997-01-01","1998-01-01","1999-01-01","2000-01-01","2001-01-01","2002-01-01","2003-01-01","2004-01-01","2005-01-01","2006-01-01","2007-01-01","2008-01-01","2009-01-01","2010-01-01","2011-01-01","2012-01-01","2013-01-01","2014-01-01","2015-01-01","2016-01-01","2017-01-01","2018-01-01","2019-01-01","2020-01-01","2021-01-01","2022-01-01","2023-01-01"],"y":[104.3,107.1,107.9,110.8,113.7,115.8,120.9,125.6,130.3,135.8,141.8,147.9,153.1,158.1,161.9,166.6,173.2,181.3,184.8,186.8,187.0,190.9,197.7,202.029,209.903,208.548,212.447,220.288,224.568,230.791,237.2,239.99,246.643,254.995,261.958,266.999,272.207,281.845,304.424,320.3],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2} ...
# <div>                            <div id="a7fefc93-c817-4099-82ff-0df78215299d" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7fefc93-c817-4099-82ff-0df78215299d")) {                    Plotly.newPlot(                        "a7fefc93-c817-4099-82ff-0df78215299d",                        [{"mode":"lines+markers","name":"monthly_market_hotness_ranking","x":["2017-08-01","2017-09-01","2017-10-01","2017-11-01","2017-12-01","2018-01-01","2018-02-01","2018-03-01","2018-04-01","2018-05-01","2018-06-01","2018-07-01","2018-08-01","2018-09-01","2018-10-01","2018-11-01","2018-12-01","2019-01-01","2019-02-01","2019-03-01","2019-04-01","2019-05-01","2019-06-01","2019-07-01","2019-08-01","2019-09-01","2019-10-01","2019-11-01","2019-12-01","2020-01-01","2020-02-01","2020-03-01","2020-04-01","2020-05-01","2020-06-01","2020-07-01","2020-08-01","2020-09-01","2020-10-01","2020-11-01","2020-12-01","2021-01-01","2021-02-01","2021-03-01","2021-04-01","2021-05-01","2021-06-01","2021-07-01","2021-08-01","2021-09-01","2021-10-01","2021-11-01","2021-12-01","2022-01-01","2022-02-01","2022-03-01","2022-04-01","2022-05-01","2022-06-01","2022-07-01","2022-08-01","2022-09-01","2022-10-01","2022-11-01","2022-12-01","2023-01-01","2023-02-01","2023-03-01","2023-04-01","2023-05-01","2023-06-01","2023-07-01","2023-08-01","2023-09-01","2023-10-01","2023-11-01","2023-12-01","2024-01-01","2024-02-01","2024-03-01","2024-04-01","2024-05-01","2024-06-01","2024-07-01","2024-08-01","2024-09-01","2024-10-01"],"y":[11.0,8.0,3.0,4.0,10.0,7.0,4.0,5.0,60.0,61.0,71.0,83.0,58.0,47.0,43.0,43.0,39.0,28.0,32.0,41.0,64.0,80.0,81.0,90.0,89.0,84.0,74.0,68.0,37.0,28.0,27.0,37.0,40.0,62.0,92.0,93.0,86.0,90.0,87.0,84.0,78.0,40.0,42.0,56.0,71.0,75.0,96.0,97.0,83.0,66.0,66.0,57.0,36.0,31.0,55.0,74.0,94.0,99.0,96.0,102.0,109.0,104.0,112.0,140.0,154.0,143.0,79.0,71.0,90.0,109.0,114.0,124.0,136.0,146.0,155.0,181.0,210.0,156.0,89.0,116.0,154.0,168.0,159.0,190.0,213.0,219.0,215.0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorsca ...

# %% [markdown]
# 1. **monthly_market_hotness_ranking**
# This field does not need to be normalized by population as it's likely already a relative measure comparing different markets.
#
# 2. **annual_consumer_price_index**
# This field does not need to be normalized by population. The CPI is already a standardized measure that tracks changes in the price level of a basket of consumer goods and services over time.

# %%
# Out:
# <div>                            <div id="3ab7fc0c-03fd-4c3e-b6bd-4a8907aa4fa6" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ab7fc0c-03fd-4c3e-b6bd-4a8907aa4fa6")) {                    Plotly.newPlot(                        "3ab7fc0c-03fd-4c3e-b6bd-4a8907aa4fa6",                        [{"mode":"lines+markers","name":"Forecasted_Smoke_Estimate","x":[1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025,2026,2027,2028,2029,2030,2031,2032,2033,2034,2035,2036,2037,2038,2039,2040,2041,2042,2043,2044,2045,2046,2047,2048,2049,2050],"y":[0.210585413557422,-0.0168441579466051,0.0849540542175494,-0.0246668985226365,-0.0242594384094879,0.0184760876063203,0.0310125471630703,0.1023581894725048,-0.0104360513706733,0.0405936904745862,0.069804999407546,0.0422361078170012,0.0375173210131281,0.0321704558312164,0.0401944684372902,0.0825979809998621,0.0822374059221787,0.1532369711708055,-0.0013363864964517,0.1153836883742248,0.0843553788538718,0.177009825223032,0.1672106443206786,0.2560391799975414,0.3743633772849258,0.2152056001406832,0.1772764416659127,0.1493497040632282,0.1439937934735576,0.0745105095300927,0.3026763866748551,0.2670958141277709,0.3487976822678417,0.1261921128702496,0.2101470617920775,0.3079004531357349,0.5279762544057272,0.3782374555026742,0.3743192299284111,0.6721453727705017,0.292491191599214,0.4796405611845292,0.6199966714155433,0.5220621175221289,0.4907842389847794,0.6168552730591194,0.6187456264192346,0.9890954326304472,0.8960040482938249,0.5287209993514163,0.489052400384572,0.5724276870580642,0.7978399728403258,0.8970219553248601,0.7940382532603493,0.77307698057365,1.005953720274388,0.524491209574516,0.5390815575136723,0.5536719054528272,0.568262253391989,0.5828526013311421,0.5974429492702978,0.6120332972094598,0.6266236451486128,0.6412139930877689,0.65580434102693,0.6703946889660858,0.6849850369052397,0.6995753848444006,0.7141657327835564,0.7287560807227114,0.7433464286618714,0.7579367766010268,0.7725271245401826,0.7871174724793424,0.8017078204184975,0.8162981683576593,0.8308885162968143,0.8454788642359683,0.8600692121751301,0.8746595601142853,0.8892499080534413,0.9038402559926002,0.918430603931756,0.933020951870912,0.947611299810071],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{ ...

# %% [markdown]
# To standardise my data and compare all these different variables accross different scales and ranges. I used the min-max scaling technique. It brings all features to the same scale (0-1), making comparisons easier. Furthuremore, plotting multiple variables on the same graph becomes more meaningful. It preserves zero values and maintains the relative distances between data points. I think that it becomes easier to identify which variables are showing the most significant changes over time.The scaled values are easily interpretable as percentages of the range. I believe that for my model, the features on similar scales can improve performance and convergence.
#
# **Formula:**
#
# The formula for Min-Max scaling is:
#
# $$X_{scaled} = \frac{X - X_{min}}{X_{max} - X_{min}}$$
#
# Where:
# - $X$ is the original value
# - $X_{min}$ is the minimum value of the feature
# - $X_{max}$ is the maximum value of the feature

# %%
annual_consumer_price_index['DATE'] = pd.to_datetime(annual_consumer_price_index['DATE'])
monthly_market_hotness_ranking['DATE'] = pd.to_datetime(monthly_market_hotness_ranking['DATE'])

annual_consumer_price_index['Year'] = annual_consumer_price_index['DATE'].dt.year
monthly_market_hotness_ranking['Year'] = monthly_market_hotness_ranking['DATE'].dt.year

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np

# Data Preparation Functions
def aggregate_monthly_to_annual(monthly_df, value_col):
    """Aggregate monthly data to annual by taking the yearly average."""
    monthly_df = monthly_df.copy()
    monthly_df['Year'] = pd.to_datetime(monthly_df['DATE']).dt.year
    annual_df = monthly_df.groupby('Year')[value_col].mean().reset_index()
    return annual_df

def backfill_with_linear_model(data, target_col, start_year, end_year):
    """Backfill missing values in the target column using a linear regression model."""
    # Create a full range of years
    full_years = pd.DataFrame({'Year': range(start_year, end_year + 1)})
    data = pd.merge(full_years, data, on='Year', how='left')
    
    # Known data for training
    known_data = data.dropna(subset=[target_col])
    if known_data.empty:
        raise ValueError(f"No known data points to fit regression for {target_col}.")
    
    # Fit regression model
    model = LinearRegression()
    model.fit(known_data[['Year']], known_data[target_col])
    
    # Predict missing values
    missing_data = data[data[target_col].isnull()]
    if not missing_data.empty:
        data.loc[missing_data.index, target_col] = model.predict(missing_data[['Year']])
    
    return data

def merge_datasets(smoke_estimate_data, annual_consumer_price_index, monthly_market_hotness_ranking):
    """Merge all datasets into a single annual DataFrame."""
    # Merge smoke estimates and annual income
    annual_df = pd.merge(smoke_estimate_data, annual_consumer_price_index, on='Year', how='outer')
    
    # Add unemployment rate
    annual_market_hotness_ranking = aggregate_monthly_to_annual(monthly_market_hotness_ranking, 'monthly_market_hotness_ranking')
    annual_df = pd.merge(annual_df, annual_market_hotness_ranking, on='Year', how='outer')
    
    return annual_df

def min_max_scale_columns(df, columns):
    """
    Apply Min-Max scaling to specified columns in a DataFrame.

    Args:
        df (pd.DataFrame): Input DataFrame.
        columns (list): List of column names to scale.

    Returns:
        pd.DataFrame: DataFrame with scaled columns.
    """
    df = df.copy()  # Avoid modifying the original DataFrame
    for col in columns:
        min_val = df[col].min()
        max_val = df[col].max()
        if min_val == max_val:  # Handle constant columns
            df[col] = 0.5  # Assign mid-value for constant columns
        else:
            df[col] = (df[col] - min_val) / (max_val - min_val)
    return df

# Full Pipeline
start_year = 1964
end_year = 2020

# Merge datasets
annual_df = merge_datasets(smoke_estimate_data, annual_consumer_price_index, monthly_market_hotness_ranking)


annual_df.head()
# Out:
#    Year  Forecasted_Smoke_Estimate DATE  annual_consumer_price_index  \
# 0  1964                   0.210585  NaT                          NaN
# 1  1965                  -0.016844  NaT                          NaN
# 2  1966                   0.084954  NaT                          NaN
# 3  1967                  -0.024667  NaT                          NaN
# 4  1968                  -0.024259  NaT                          NaN
#
#    monthly_market_hotness_ranking
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %%
# Remove rows with missing values (NaN) from the dataset
df_annual_clean = annual_df.dropna()

# Print the number of rows left after cleaning the data
print(f"Number of rows after removing NaN values: {len(df_annual_clean)}")

# Calculate the correlation matrix using Pearson's method
correlation_matrix = df_annual_clean.corr(method='pearson')

# Exclude 'Forecasted_Smoke_Estimate', 'Year', and 'DATE' from the correlations
columns_to_exclude = ['Forecasted_Smoke_Estimate', 'Year', 'DATE']
smoke_correlation = correlation_matrix[['Forecasted_Smoke_Estimate']].drop(index=columns_to_exclude, errors='ignore')

# Print the correlation values for the 'Forecasted_Smoke_Estimate' column
print("Correlations with 'Forecasted_Smoke_Estimate':")
print(smoke_correlation)

# Prepare annotations with variable names and their corresponding correlation values
annotations = smoke_correlation.index + "\n " + "Correlation: " + smoke_correlation['Forecasted_Smoke_Estimate'].round(2).astype(str)

# Create a heatmap to display correlations with 'Forecasted_Smoke_Estimate'
plt.figure(figsize=(6, 8))  # Adjust figure size for better clarity
sns.heatmap(
    smoke_correlation,
    annot=annotations.values.reshape(-1, 1),  # Annotate each cell with variable name and value
    fmt="",  # Prevent scientific notation formatting
    cmap='coolwarm',  # Use the same color map as before
    vmin=-1, vmax=1, center=0,  # Maintain consistent scaling
    cbar=True  # Add a color bar
)
plt.title("Correlation Heatmap: Forecasted Smoke Estimate")  # Title for the heatmap
plt.ylabel("Variables")  # Add y-axis label
plt.xlabel("Forecasted Smoke Estimate")  # Add x-axis label
plt.show()  # Display the heatmap
# Out:
# Number of rows after removing NaN values: 7
# Correlations with 'Forecasted_Smoke_Estimate':
#                                 Forecasted_Smoke_Estimate
# annual_consumer_price_index                     -0.738031
# monthly_market_hotness_ranking                  -0.633250

# %%
# Assuming the dataframe is called 'df'
df_annual_clean = annual_df.dropna()

# Check the number of remaining rows
print(f"Number of rows after removing NaN values: {len(df_annual_clean)}")

correlation_matrix = df_annual_clean.corr(method='pearson')
print("Correlation Matrix:")
print(correlation_matrix['Forecasted_Smoke_Estimate'])
# Out:
# Number of rows after removing NaN values: 7
# Correlation Matrix:
# Year                             -0.721110
# Forecasted_Smoke_Estimate         1.000000
# DATE                             -0.721309
# annual_consumer_price_index      -0.738031
# monthly_market_hotness_ranking   -0.633250
# Name: Forecasted_Smoke_Estimate, dtype: float64

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Backfill missing values
for col in ['Forecasted_Smoke_Estimate', 'annual_consumer_price_index', 
            'monthly_market_hotness_ranking']:
    annual_df = backfill_with_linear_model(annual_df, col, start_year, end_year)
    
annual_df = min_max_scale_columns(annual_df, [
    'annual_consumer_price_index', 
    'monthly_market_hotness_ranking'
])


# Resulting DataFrame
annual_df.head()
# Out:
#    Year  Forecasted_Smoke_Estimate DATE  annual_consumer_price_index  \
# 0  1964                   0.210585  NaT                     0.000000
# 1  1965                  -0.016844  NaT                     0.017433
# 2  1966                   0.084954  NaT                     0.034866
# 3  1967                  -0.024667  NaT                     0.052299
# 4  1968                  -0.024259  NaT                     0.069732
#
#    monthly_market_hotness_ranking
# 0                        0.000000
# 1                        0.017992
# 2                        0.035984
# 3                        0.053976
# 4                        0.071968

# %%
# Create the figure
fig = go.Figure()

# Add a trace for each column
for column in annual_df.columns:
    if column != 'Year':
        fig.add_trace(go.Scatter(
            x=annual_df['Year'],
            y=annual_df[column],
            mode='lines+markers',
            name=column
        ))

# Update the layout
fig.update_layout(
    title='Annual Market Data',
    xaxis_title='Year',
    yaxis_title='Values',
    height=600,
    width=1000,
    legend_title='Variables',
    hovermode='x unified'
)

# Add range slider and selector
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=10, label="10y", step="year", stepmode="backward"),
            dict(count=20, label="20y", step="year", stepmode="backward"),
            dict(count=50, label="50y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)

# Show the plot
fig.show()
# Out:
# C:\Users\navya\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# <div>                            <div id="e593fe8d-ef47-44ac-9e62-4302bfd66a3f" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e593fe8d-ef47-44ac-9e62-4302bfd66a3f")) {                    Plotly.newPlot(                        "e593fe8d-ef47-44ac-9e62-4302bfd66a3f",                        [{"mode":"lines+markers","name":"Forecasted_Smoke_Estimate","x":[1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":[0.210585413557422,-0.0168441579466051,0.0849540542175494,-0.0246668985226365,-0.0242594384094879,0.0184760876063203,0.0310125471630703,0.1023581894725048,-0.0104360513706733,0.0405936904745862,0.069804999407546,0.0422361078170012,0.0375173210131281,0.0321704558312164,0.0401944684372902,0.0825979809998621,0.0822374059221787,0.1532369711708055,-0.0013363864964517,0.1153836883742248,0.0843553788538718,0.177009825223032,0.1672106443206786,0.2560391799975414,0.3743633772849258,0.2152056001406832,0.1772764416659127,0.1493497040632282,0.1439937934735576,0.0745105095300927,0.3026763866748551,0.2670958141277709,0.3487976822678417,0.1261921128702496,0.2101470617920775,0.3079004531357349,0.5279762544057272,0.3782374555026742,0.3743192299284111,0.6721453727705017,0.292491191599214,0.4796405611845292,0.6199966714155433,0.5220621175221289,0.4907842389847794,0.6168552730591194,0.6187456264192346,0.9890954326304472,0.8960040482938249,0.5287209993514163,0.489052400384572,0.5724276870580642,0.7978399728403258,0.8970219553248601,0.7940382532603493,0.77307698057365,1.005953720274388],"type":"scatter"},{"mode":"lines+markers","name":"DATE","x":[1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"1984-01-01T00:00:00","1985-01-01T00:00:00","1986-01-01T00:00:00","1987-01-01T00:00:00","1988-01-01T00:00:00","1989-01-01T00:00:00","1990-01-01T00:00:00","1991-01-01T00:00:00","1992-01-01T00:00:00","1993-01-01T00:00:00","1994-01-01T00:00:00","1995-01-01T00:00:00","1996-01-01T00:00:00","1997-01-01T00:00:00","1998-01-01T00:00:00","1999-01-01T00:00:00","2000-01-01T00:00:00","2001-01-01T00:00:00","2002-01-01T00:00:00","2003-01-01T00:00:00","2004-01-01T00:00:00","2005-01-01T00:00:00","2006-01-01T00:00:00","2007-01-01T00:00:00","2008-01-01T00:00:00","2009-01-01T00:00:00","2010-01-01T00:00:00","2011-01-01T00:00:00","2012-01-01T00:00:00","2013-01-01T00:00:00","2014-01-01T00:00:00","2015-01-01T00:00:00","2016-01-01T00:00:00","2017-01-01T00:00:00","2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00"],"type":"scatter"},{"mode":"lines+markers","name":"annual_consumer_price_index","x":[1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":[0.0,0.01743304456179006,0.0348660891235734,0.05229913368536346,0.06973217824715353,0.08716522280894358,0.10459826737073365,0.1220313119325237,0.13946435649431377,0.15689740105609712,0.17433044561788716,0.19176349017967723,0.2091965347414673,0.22662957930325736,0.2440626238650474,0.26149566842683747,0.2789287129886208,0.2963617575504109,0.31379480211220095,0.33122784667399097,0.379543682 ...

# %%
# Backfill missing values
for col in ['Forecasted_Smoke_Estimate', 'annual_consumer_price_index', 
            'monthly_market_hotness_ranking']:
    annual_df = backfill_with_linear_model(annual_df, col, start_year, end_year)
    
annual_df = min_max_scale_columns(annual_df, [
    'annual_consumer_price_index', 
    'monthly_market_hotness_ranking'
])


# Resulting DataFrame
annual_df.head()
# Out:
#    Year  Forecasted_Smoke_Estimate DATE  annual_consumer_price_index  \
# 0  1964                   0.210585  NaT                     0.000000
# 1  1965                  -0.016844  NaT                     0.017433
# 2  1966                   0.084954  NaT                     0.034866
# 3  1967                  -0.024667  NaT                     0.052299
# 4  1968                  -0.024259  NaT                     0.069732
#
#    monthly_market_hotness_ranking
# 0                        0.000000
# 1                        0.017992
# 2                        0.035984
# 3                        0.053976
# 4                        0.071968

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
from prophet import Prophet
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
import plotly.graph_objects as go

# Filter the data for the specified year range
filtered_data = annual_df[(annual_df['Year'] >= 1990)]

# Create the figure
fig = go.Figure()

# Add traces for each column
fig.add_trace(go.Scatter(
    x=filtered_data['Year'],
    y=filtered_data['Forecasted_Smoke_Estimate'],
    mode='lines+markers',
    name='Forecasted Smoke Estimate'
))

fig.add_trace(go.Scatter(
    x=filtered_data['Year'],
    y=filtered_data['annual_consumer_price_index'],
    mode='lines+markers',
    name='Annual Consumer Price Index'
))

# Update the layout
fig.update_layout(
    title='Forecasted Smoke Estimate and Annual Consumer Price Index (1980-2023)',
    xaxis_title='Year',
    yaxis_title='Values',
    legend_title='Variables',
    height=600,
    width=1000
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="48d240e1-c036-404f-877e-f1630d08cdd1" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48d240e1-c036-404f-877e-f1630d08cdd1")) {                    Plotly.newPlot(                        "48d240e1-c036-404f-877e-f1630d08cdd1",                        [{"mode":"lines+markers","name":"Forecasted Smoke Estimate","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":[0.1772764416659127,0.1493497040632282,0.1439937934735576,0.0745105095300927,0.3026763866748551,0.2670958141277709,0.3487976822678417,0.1261921128702496,0.2101470617920775,0.3079004531357349,0.5279762544057272,0.3782374555026742,0.3743192299284111,0.6721453727705017,0.292491191599214,0.4796405611845292,0.6199966714155433,0.5220621175221289,0.4907842389847794,0.6168552730591194,0.6187456264192346,0.9890954326304472,0.8960040482938249,0.5287209993514163,0.489052400384572,0.5724276870580642,0.7978399728403258,0.8970219553248601,0.7940382532603493,0.77307698057365,1.005953720274388],"type":"scatter"},{"mode":"lines+markers","name":"Annual Consumer Price Index","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"y":[0.44088463197477035,0.45825225032500244,0.4756198686752347,0.4959436773829532,0.5181151050641006,0.5406560565399339,0.559871293863595,0.5783474835978846,0.5923893877959446,0.6097570061461768,0.6341455765954389,0.664077003964988,0.6770103367789908,0.6844008126727066,0.6851398602620782,0.699551288254824,0.7246789062934578,0.7406755913654056,0.7697718949589648,0.7647648475409724,0.7791725802957714,0.8081469410370843,0.8239625594496361,0.8469580251929328,0.8706408051943452,0.8809505190660788,0.9055349371265244,0.9363975644586817,0.9621275062826534,0.9807552007727641,1.0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111 ...

# %%
# Filter the data for the specified year range
filtered_data = annual_df[(annual_df['Year'] >= 2017)]

# Create the figure
fig = go.Figure()

# Add traces for each column
fig.add_trace(go.Scatter(
    x=filtered_data['Year'],
    y=filtered_data['Forecasted_Smoke_Estimate'],
    mode='lines+markers',
    name='Forecasted Smoke Estimate'
))

fig.add_trace(go.Scatter(
    x=filtered_data['Year'],
    y=filtered_data['monthly_market_hotness_ranking'],
    mode='lines+markers',
    name='Annual Market Hotness Ranking'
))

# Update the layout
fig.update_layout(
    title='Forecasted Smoke Estimate and Market Hotness Ranking(1980-2023)',
    xaxis_title='Year',
    yaxis_title='Values',
    legend_title='Variables',
    height=600,
    width=1000
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="e885e14e-e794-47b1-ad50-0435764b1ed2" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e885e14e-e794-47b1-ad50-0435764b1ed2")) {                    Plotly.newPlot(                        "e885e14e-e794-47b1-ad50-0435764b1ed2",                        [{"mode":"lines+markers","name":"Forecasted Smoke Estimate","x":[2017,2018,2019,2020],"y":[0.8970219553248601,0.7940382532603493,0.77307698057365,1.005953720274388],"type":"scatter"},{"mode":"lines+markers","name":"Annual Market Hotness Ranking","x":[2017,2018,2019,2020],"y":[0.946199072428824,0.9787825215960942,0.9973009568108105,1.0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","mar ...

# %%
def prepare_data(df):
    """
    Prepare data for time series analysis.
    
    This function prepares the input dataframe by setting the 'Year' column as the datetime index, 
    handling missing values through interpolation, and using forward/backward filling methods for any
    remaining missing values at the edges.
    """
    # Convert Year to proper datetime index
    df = df.copy()  # Create a copy of the dataframe to avoid modifying the original
    df.index = pd.to_datetime(df['Year'].astype(str), format='%Y')  # Convert 'Year' column to datetime and set as index
    
    # Handle missing values
    for column in df.columns:
        if df[column].isnull().any():  # Check if there are any missing values in the column
            # Use linear interpolation first
            df[column] = df[column].interpolate(method='linear')  # Fill missing values with linear interpolation
            # If any remaining NaN at the edges, use forward/backward fill
            df[column] = df[column].fillna(method='ffill').fillna(method='bfill')  # Forward fill or backward fill
            
    return df

# %%
def build_sarima_model(data, target_col, smoke_col, train_end_year=2020):
    """
    Build SARIMA model with exogenous variable (smoke estimate).
    
    This function splits the data into training and test sets, fits a SARIMA model with the given target
    variable and an exogenous smoke estimate, and returns the model results along with the training and test sets.
    """
    # Split data into train and test
    train = data[data.index.year <= train_end_year]  # Training set: data until the specified year
    test = data[data.index.year > train_end_year]  # Test set: data after the specified year
    
    # Fit SARIMA model
    model = SARIMAX(train[target_col],  # Target column for SARIMA model
                    exog=train[smoke_col],  # Exogenous variable (smoke estimate)
                    order=(1, 1, 1),  # ARIMA model order
                    seasonal_order=(1, 1, 1, 12))  # Seasonal components of the SARIMA model
    
    results = model.fit()  # Fit the SARIMA model
    
    return results, train, test

# %%
def forecast_scenarios(model, train_data, future_periods, smoke_col):
    """
    Generate forecasts for both increasing and constant smoke scenarios.
    
    This function generates two forecast scenarios based on the smoke estimate: 
    one where smoke increases over time and one where it remains constant. 
    It returns the forecasts for both scenarios along with the future smoke values.
    """
    # Create future smoke scenarios
    last_smoke = train_data[smoke_col].iloc[-1]  # Last observed smoke level
    smoke_trend = (train_data[smoke_col].iloc[-1] - train_data[smoke_col].iloc[0]) / len(train_data)  # Smoke trend
    
    # Increasing scenario
    future_smoke_increasing = np.array([last_smoke + smoke_trend * i for i in range(1, future_periods + 1)])
    
    # Constant scenario
    future_smoke_constant = np.array([last_smoke] * future_periods)
    
    # Generate forecasts
    forecast_increasing = model.get_forecast(steps=future_periods, exog=future_smoke_increasing)
    forecast_constant = model.forecast(future_periods, exog=future_smoke_constant)
    
    # Extract confidence intervals for increasing scenario
    conf_int_increasing = forecast_increasing.conf_int(alpha=0.05)
    forecast_mean_increasing = forecast_increasing.predicted_mean
    
    return forecast_mean_increasing, forecast_constant, conf_int_increasing, future_smoke_increasing, future_smoke_constant

# %%
def plot_forecasts(data, target_col, forecast_inc, conf_int_inc, forecast_const, train_end_year):
    """
    Plot the forecasts against actual data.
    
    This function plots the actual data up to the training year and the forecasts for both increasing and constant
    smoke scenarios after the training year. It includes confidence intervals for the increasing smoke scenario.
    """
    plt.figure(figsize=(12, 6))  # Set up the figure for plotting
    
    # Plot historical data
    plt.plot(data.index[data.index.year <= train_end_year], 
             data[target_col][data.index.year <= train_end_year], 
             'b-', label='Historical Data')  # Plot historical data in blue
    
    # Plot forecasts
    future_dates = pd.date_range(start=str(train_end_year+1), 
                                 periods=len(forecast_inc), 
                                 freq='Y')  # Generate future dates for plotting
    
    # Forecast lines for increasing and constant smoke
    plt.plot(future_dates, forecast_inc, 'r--', label='Forecast (Increasing Smoke)')  # Forecast for increasing smoke
    plt.plot(future_dates, forecast_const, 'g--', label='Forecast (Constant Smoke)')  # Forecast for constant smoke
    
    # Confidence intervals for increasing smoke
    plt.fill_between(future_dates, 
                     conf_int_inc.iloc[:, 0], 
                     conf_int_inc.iloc[:, 1], 
                     color='red', alpha=0.2)  # Confidence interval
    
    # Adding labels and legend
    plt.title(f'Forecasts for {target_col}')
    plt.xlabel('Year')
    plt.ylabel('Value')
    plt.legend(loc='best')  # Explicitly call legend and set the location
    plt.grid(True)
    plt.show()

# %%
# Prepare data
data = prepare_data(annual_df)  # Preprocess data for time series analysis

# Variables to analyze
target_variables = ['annual_consumer_price_index',
                       'monthly_market_hotness_ranking']

# Future periods to forecast
future_periods = 30  # Forecast from 2024 to 2050

# Results dictionary to store forecasts
results = {}

# 1. Individual SARIMA models for each target
for target in target_variables:
    print(f"\nAnalyzing {target}")

    # Build SARIMA model
    model, train, test = build_sarima_model(
        data,
        target,
        'Forecasted_Smoke_Estimate',
        train_end_year=2020
    )

    # Generate forecasts
    forecast_inc, forecast_const, conf_int_inc, smoke_inc, smoke_const = forecast_scenarios(
        model,
        train,
        future_periods,
        'Forecasted_Smoke_Estimate'
    )

    # Store results
    results[target] = {
        'forecast_increasing': forecast_inc,
        'forecast_constant': forecast_const,
        'confidence_interval_increasing': conf_int_inc,
        'actual_data': data[target]
    }

    # Plot results
    plot_forecasts(data, target, forecast_inc, conf_int_inc, forecast_const, 2020)

# Print summary statistics
print("\nImpact Analysis:")
for target in target_variables:
    inc_forecast = results[target]['forecast_increasing']
    const_forecast = results[target]['forecast_constant']

    # Calculate average impact
    avg_impact = ((inc_forecast - const_forecast) / const_forecast * 100).mean()  # Calculate average impact

    print(f"\n{target}:")
    print(f"Average predicted impact: {avg_impact:.2f}%")
    print(f"Maximum predicted impact: {((inc_forecast - const_forecast) / const_forecast * 100).max():.2f}%")
# Out:
# C:\Users\navya\AppData\Local\Temp\ipykernel_30148\2835577655.py:19: FutureWarning:
#
# Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency AS-JAN will be used.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency AS-JAN will be used.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning:
#
# Non-invertible starting seasonal moving average Using zeros as starting parameters.
# Analyzing annual_consumer_price_index
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# Analyzing monthly_market_hotness_ranking
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency AS-JAN will be used.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency AS-JAN will be used.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning:
#
# Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning:
#
# Non-invertible starting seasonal moving average Using zeros as starting parameters.
# Impact Analysis:
#
# annual_consumer_price_index:
# Average predicted impact: 0.04%
# Maximum predicted impact: 0.07%
#
# monthly_market_hotness_ranking:
# Average predicted impact: -0.02%
# Maximum predicted impact: -0.00%

# %%
def prepare_data(df):
    """
    Prepare data for time series analysis
    """
    # Convert Year to proper datetime index
    df = df.copy()
    df.index = pd.to_datetime(df['Year'].astype(str), format='%Y')
    
    # Handle missing values
    for column in df.columns:
        if df[column].isnull().any():
            # Use linear interpolation first
            df[column] = df[column].interpolate(method='linear')
            # If any remaining NaN at the edges, use forward/backward fill
            df[column] = df[column].fillna(method='ffill').fillna(method='bfill')
    
    return df


def backfill_with_regression(df, target_col, start_year):
    """
    Backfill data using linear regression.
    """
    df = df.copy()
    # Ensure year is part of the data for regression
    df['Year'] = df.index.year
    
    # Filter rows with known values
    known_data = df.dropna(subset=[target_col])
    if known_data.empty:
        raise ValueError("No known data points to fit regression.")
    
    # Fit a linear regression model
    model = LinearRegression()
    X = known_data[['Year']]
    y = known_data[target_col]
    model.fit(X, y)
    
    # Predict missing values for years < min known year
    missing_years = [year for year in range(start_year, known_data['Year'].min())]
    missing_data = pd.DataFrame({'Year': missing_years})
    missing_data[target_col] = model.predict(missing_data[['Year']])
    missing_data.index = pd.to_datetime(missing_data['Year'].astype(str))
    
    # Combine with the original dataframe
    df = pd.concat([missing_data[[target_col]], df])
    df = df.sort_index()
    return df

def build_sarima_model(data, target_col, smoke_col, train_end_year=2020):
    """
    Build SARIMA model with exogenous variable (smoke estimate)
    """
    # Split data into train and test
    train = data[data.index.year <= train_end_year]
    test = data[data.index.year > train_end_year]
    
    # Fit SARIMA model
    model = SARIMAX(train[target_col],
                    exog=train[smoke_col],
                    order=(1, 1, 1),
                    seasonal_order=(1, 1, 1, 12))
    
    results = model.fit()
    
    return results, train, test

def forecast_scenarios(model, train_data, future_periods, smoke_col):
    """
    Generate forecasts for both increasing and constant smoke scenarios
    """
    # Create future smoke scenarios
    last_smoke = train_data[smoke_col].iloc[-1]
    smoke_trend = (train_data[smoke_col].iloc[-1] - train_data[smoke_col].iloc[0]) / len(train_data)
    
    # Increasing scenario
    future_smoke_increasing = np.array([last_smoke + smoke_trend * i for i in range(1, future_periods + 1)])
    
    # Constant scenario
    future_smoke_constant = np.array([last_smoke] * future_periods)
    
    # Generate forecasts
    forecast_increasing = model.forecast(future_periods, exog=future_smoke_increasing)
    forecast_constant = model.forecast(future_periods, exog=future_smoke_constant)
    
    return forecast_increasing, forecast_constant, future_smoke_increasing, future_smoke_constant


def plot_forecasts(data, target_col, forecast_inc, forecast_const, train_end_year):
    """
    Plot the forecasts against actual data
    """
    plt.figure(figsize=(12, 6))
    
    # Plot historical data
    plt.plot(data.index[data.index.year <= train_end_year], 
             data[target_col][data.index.year <= train_end_year], 
             'b-', label='Historical Data')
    
    # Plot forecasts
    future_dates = pd.date_range(start=str(train_end_year+1), 
                                periods=len(forecast_inc), 
                                freq='Y')
    
    plt.plot(future_dates, forecast_inc, 'r--', label='Forecast (Increasing Smoke)')
    plt.plot(future_dates, forecast_const, 'g--', label='Forecast (Constant Smoke)')
    
    plt.title(f'Forecasts for {target_col}')
    plt.xlabel('Year')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True)
    plt.show()

def main():
    # Read your data
    # Replace this with your actual data loading
#     df = pd.read_csv('your_data.csv')
    
    # Prepare data
    data = prepare_data(annual_df)
    
    # Variables to analyze
    target_variables = ['annual_consumer_price_index',
                       'monthly_market_hotness_ranking']
    
#     for col in target_variables:
#         print(f"Backfilling {col} with regression.")
#         data = backfill_with_regression(data, col, 1964)
    
    # Future periods to forecast
    future_periods = 30  # 2024 to 2050
    
    # Results dictionary
    results = {}
    
    # 1. Individual SARIMA models for each target
    for target in target_variables:
        print(f"\nAnalyzing {target}")
        
        # Build model
        model, train, test = build_sarima_model(
            data,
            target,
            'Forecasted_Smoke_Estimate',
            train_end_year=2020
        )
        
        # Generate forecasts
        forecast_inc, forecast_const, smoke_inc, smoke_const = forecast_scenarios(
            model,
            train,
            future_periods,
            'Forecasted_Smoke_Estimate'
        )
        
        # Store results
        results[target] = {
            'forecast_increasing': forecast_inc,
            'forecast_constant': forecast_const,
            'actual_data': data[target]
        }
        
        # Plot results
        plot_forecasts(data, target, forecast_inc, forecast_const, 2020)

    # Print summary statistics
    print("\nImpact Analysis:")
    for target in target_variables:
        inc_forecast = results[target]['forecast_increasing']
        const_forecast = results[target]['forecast_constant']
        
        # Calculate average impact
        avg_impact = ((inc_forecast - const_forecast) / const_forecast * 100).mean()
        
        print(f"\n{target}:")
        print(f"Average predicted impact: {avg_impact:.2f}%")
        print(f"Maximum predicted impact: {((inc_forecast - const_forecast) / const_forecast * 100).max():.2f}%")

    return results

if __name__ == "__main__":
    results = main()
# Out:
# C:\Users\navya\AppData\Local\Temp\ipykernel_30148\2442897901.py:15: FutureWarning:
#
# Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency AS-JAN will be used.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency AS-JAN will be used.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning:
#
# Non-invertible starting seasonal moving average Using zeros as starting parameters.
# Analyzing annual_consumer_price_index
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# Analyzing monthly_market_hotness_ranking
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency AS-JAN will be used.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency AS-JAN will be used.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning:
#
# Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning:
#
# Non-invertible starting seasonal moving average Using zeros as starting parameters.
# Impact Analysis:
#
# annual_consumer_price_index:
# Average predicted impact: 0.04%
# Maximum predicted impact: 0.07%
#
# monthly_market_hotness_ranking:
# Average predicted impact: -0.02%
# Maximum predicted impact: -0.00%

# %%
# Data Preparation Functions
def transform_yearly_to_monthly(yearly_df, value_col):
    """Transform yearly data to monthly data by duplicating each year's value for all months."""
    yearly_df = yearly_df.copy()
    yearly_df['DATE'] = pd.to_datetime(yearly_df['Year'].astype(str) + '-01-01')
    monthly_df = yearly_df.set_index('DATE').resample('M').ffill()
    return monthly_df[[value_col]]

def prepare_monthly_data(df, value_col):
    """Ensure monthly data has proper datetime index and fill missing values."""
    df = df.copy()
    df = df.reset_index()
    df['DATE'] = pd.to_datetime(df['DATE'])
    df.set_index('DATE', inplace=True)
    df = df.resample('M').mean()  # Ensure consistent monthly frequency
    df[value_col] = df[value_col].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
    return df


# Transform Data
smoke_monthly = transform_yearly_to_monthly(smoke_estimate_data, 'Forecasted_Smoke_Estimate')
monthly_market_hotness_ranking = prepare_monthly_data(monthly_market_hotness_ranking, 'monthly_market_hotness_ranking')


# Combine All Data
monthly_df = pd.concat([smoke_monthly, monthly_market_hotness_ranking], axis=1)
monthly_df = monthly_df.dropna()  # Ensure no missing values
monthly_df
# Out:
# C:\Users\navya\AppData\Local\Temp\ipykernel_30148\3620651413.py:16: FutureWarning:
#
# Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#             Forecasted_Smoke_Estimate  index  monthly_market_hotness_ranking  \
# DATE
# 2017-08-31                   0.897022    0.0                            11.0
# 2017-09-30                   0.897022    1.0                             8.0
# 2017-10-31                   0.897022    2.0                             3.0
# 2017-11-30                   0.897022    3.0                             4.0
# 2017-12-31                   0.897022    4.0                            10.0
# ...                               ...    ...                             ...
# 2024-06-30                   0.568262   82.0                           159.0
# 2024-07-31                   0.568262   83.0                           190.0
# 2024-08-31                   0.568262   84.0                           213.0
# 2024-09-30                   0.568262   85.0                           219.0
# 2024-10-31                   0.568262   86.0                           215.0
#
#               Year
# DATE
# 2017-08-31  2017.0
# 2017-09-30  2017.0
# 2017-10-31  2017.0
# 2017-11-30  2017.0
# 2017-12-31  2017.0
# ...            ...
# 2024-06-30  2024.0
# 2024-07-31  2024.0
# 2024-08-31  2024.0
# 2024-09-30  2024.0
# 2024-10-31  2024.0
#
# [87 rows x 4 columns]

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np

# Data Preparation Functions
def transform_yearly_to_monthly(yearly_df, value_col):
    """Transform yearly data to monthly data by duplicating each year's value for all months."""
    yearly_df = yearly_df.copy()
    yearly_df['DATE'] = pd.to_datetime(yearly_df['Year'].astype(str) + '-01-01')
    monthly_df = yearly_df.set_index('DATE').resample('M').ffill()
    return monthly_df[[value_col]]

def prepare_monthly_data(df, value_col):
    """Ensure monthly data has proper datetime index and fill missing values."""
    df = df.copy()
    df = df.reset_index()
    df['DATE'] = pd.to_datetime(df['DATE'])
    df.set_index('DATE', inplace=True)
    df = df.resample('M').mean()  # Ensure consistent monthly frequency
    df[value_col] = df[value_col].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
    return df

def backfill_with_linear_model(data, target_col, feature_cols):
    """Backfill missing values in the target column using a linear model."""
    df = data.copy()
    # Prepare data for modeling
    train_data = df.dropna(subset=feature_cols + [target_col])  # Rows with no missing values
    predict_data = df[df[target_col].isnull()]  # Rows where target_col is missing

    if predict_data.empty:
        return df

    # Train a linear regression model
    X_train = train_data[feature_cols]
    y_train = train_data[target_col]
    model = LinearRegression()
    model.fit(X_train, y_train)

    # Predict missing values
    X_predict = predict_data[feature_cols]
    df.loc[predict_data.index, target_col] = model.predict(X_predict)
    return df

# Example Transformation Pipeline
smoke_monthly = transform_yearly_to_monthly(smoke_estimate_data, 'Forecasted_Smoke_Estimate')
monthly_market_hotness_ranking = prepare_monthly_data(monthly_market_hotness_ranking, 'monthly_market_hotness_ranking')



# Combine Data
monthly_df = pd.concat([smoke_monthly, monthly_market_hotness_ranking], axis=1)

# Backfill missing values
features = ['Forecasted_Smoke_Estimate']  # Use smoke estimates as a feature
monthly_df = backfill_with_linear_model(monthly_df, 'monthly_market_hotness_ranking', features)

# Ensure no remaining missing values
monthly_df = monthly_df.fillna(method='ffill').fillna(method='bfill')

monthly_df = monthly_df.reset_index()
monthly_df = monthly_df[['DATE', 'Forecasted_Smoke_Estimate', 'monthly_market_hotness_ranking']]
monthly_df = monthly_df[monthly_df['DATE'] < "2021-01-01"]
monthly_df.head()
# Out:
# C:\Users\navya\AppData\Local\Temp\ipykernel_30148\965874632.py:20: FutureWarning:
#
# Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# C:\Users\navya\AppData\Local\Temp\ipykernel_30148\965874632.py:58: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#         DATE  Forecasted_Smoke_Estimate  monthly_market_hotness_ranking
# 0 1964-01-31                   0.210585                      154.896379
# 1 1964-02-29                   0.210585                      154.896379
# 2 1964-03-31                   0.210585                      154.896379
# 3 1964-04-30                   0.210585                      154.896379
# 4 1964-05-31                   0.210585                      154.896379

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.vector_ar.var_model import VAR
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

def prepare_monthly_data(df):
    df = df.copy()
    df['DATE'] = pd.to_datetime(df['DATE'])
    df.set_index('DATE', inplace=True)
    
    for column in df.columns:
        if df[column].isnull().any():
            df[column] = df[column].interpolate(method='linear')
            df[column] = df[column].fillna(method='ffill').fillna(method='bfill')
    
    return df

def build_sarima_model(data, target_col, smoke_col, train_end_date='2020-12-31'):
    train = data[data.index <= train_end_date]
    test = data[data.index > train_end_date]
    
    model = SARIMAX(train[target_col],
                    exog=train[smoke_col],
                    order=(2, 1, 2),
                    seasonal_order=(1, 1, 1, 12))
    
    results = model.fit()
    
    return results, train, test

def forecast_scenarios(model, train_data, future_periods, smoke_col):
    last_smoke = train_data[smoke_col].iloc[-1]
    smoke_trend = (train_data[smoke_col].iloc[-1] - train_data[smoke_col].iloc[0]) / len(train_data)
    
    future_smoke_increasing = np.array([last_smoke + smoke_trend * i for i in range(1, future_periods + 1)])
    future_smoke_constant = np.array([last_smoke] * future_periods)
    
    forecast_increasing = model.forecast(future_periods, exog=future_smoke_increasing)
    forecast_constant = model.forecast(future_periods, exog=future_smoke_constant)
    
    return forecast_increasing, forecast_constant, future_smoke_increasing, future_smoke_constant


def plot_forecasts(data, target_col, forecast_inc, forecast_const, train_end_date):
    plt.figure(figsize=(12, 6))
    
    plt.plot(data.index[data.index <= train_end_date], 
             data[target_col][data.index <= train_end_date], 
             'b-', label='Historical Data')
    
    future_dates = pd.date_range(start=pd.to_datetime(train_end_date) + pd.Timedelta(days=1), 
                                periods=len(forecast_inc), 
                                freq='M')
    
    plt.plot(future_dates, forecast_inc, 'r--', label='Forecast (Increasing Smoke)')
    plt.plot(future_dates, forecast_const, 'g--', label='Forecast (Constant Smoke)')
    
    plt.title(f'Forecasts for {target_col}')
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True)
    plt.show()

def main():
    # Assuming monthly_df is your input DataFrame
    data = prepare_monthly_data(monthly_df)
    
    target_variables = ['monthly_market_hotness_ranking']
    
    future_periods = 12 * 26  # Monthly data from 2025 to 2050
    
    results = {}
    
    for target in target_variables:
        print(f"\nAnalyzing {target}")
        
        model, train, test = build_sarima_model(
            data,
            target,
            'Forecasted_Smoke_Estimate',
            train_end_date='2020-12-31'
        )
        
        forecast_inc, forecast_const, smoke_inc, smoke_const = forecast_scenarios(
            model,
            train,
            future_periods,
            'Forecasted_Smoke_Estimate'
        )
        
        results[target] = {
            'forecast_increasing': forecast_inc,
            'forecast_constant': forecast_const,
            'actual_data': data[target]
        }
        
        plot_forecasts(data, target, forecast_inc, forecast_const, '2020-12-31')

    
    print("\nImpact Analysis:")
    for target in target_variables:
        inc_forecast = results[target]['forecast_increasing']
        const_forecast = results[target]['forecast_constant']
        
        avg_impact = ((inc_forecast - const_forecast) / const_forecast * 100).mean()
        
        print(f"\n{target}:")
        print(f"Average predicted impact: {avg_impact:.2f}%")
        print(f"Maximum predicted impact: {((inc_forecast - const_forecast) / const_forecast * 100).max():.2f}%")

    return results

if __name__ == "__main__":
    results = main()
# Out:
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency M will be used.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency M will be used.
# Analyzing monthly_market_hotness_ranking
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# Impact Analysis:
#
# monthly_market_hotness_ranking:
# Average predicted impact: -51.34%
# Maximum predicted impact: -0.20%

# %%
def forecast_scenarios(model, train_data, future_periods, smoke_col):
    last_smoke = train_data[smoke_col].iloc[-1]
    smoke_trend = (train_data[smoke_col].iloc[-1] - train_data[smoke_col].iloc[0]) / len(train_data)
    
    future_smoke_increasing = np.array([last_smoke + smoke_trend * i for i in range(1, future_periods + 1)])
    future_smoke_constant = np.array([last_smoke] * future_periods)
    
    # Forecast for increasing smoke with confidence intervals
    forecast_increasing = model.get_forecast(steps=future_periods, exog=future_smoke_increasing)
    forecast_constant = model.forecast(future_periods, exog=future_smoke_constant)
    
    # Get the confidence intervals for the increasing smoke forecast
    conf_int_increasing = forecast_increasing.conf_int(alpha=0.01)  # 99% CI (1% significance level)
    
    return forecast_increasing.predicted_mean, forecast_constant, future_smoke_increasing, future_smoke_constant, conf_int_increasing


def plot_forecasts(data, target_col, forecast_inc, forecast_const, conf_int_inc, train_end_date):
    plt.figure(figsize=(12, 6))
    
    # Plot historical data
    plt.plot(data.index[data.index <= train_end_date], 
             data[target_col][data.index <= train_end_date], 
             'b-', label='Historical Data')
    
    future_dates = pd.date_range(start=pd.to_datetime(train_end_date) + pd.Timedelta(days=1), 
                                periods=len(forecast_inc), 
                                freq='M')
    
    # Plot the forecasts for both increasing and constant smoke
    plt.plot(future_dates, forecast_inc, 'r--', label='Forecast (Increasing Smoke)')
    plt.plot(future_dates, forecast_const, 'g--', label='Forecast (Constant Smoke)')
    
    # Plot the confidence intervals for increasing smoke forecast
    plt.fill_between(future_dates, 
                     conf_int_inc.iloc[:, 0], 
                     conf_int_inc.iloc[:, 1], 
                     color='red', alpha=0.2, label='99% Confidence Interval')  # Confidence interval fill
    
    plt.title(f'Forecasts for {target_col}')
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True)
    plt.show()

def main():
    # Assuming monthly_df is your input DataFrame
    data = prepare_monthly_data(monthly_df)
    
    target_variables = ['monthly_market_hotness_ranking']
    
    future_periods = 12 * 26  # Monthly data from 2025 to 2050
    
    results = {}
    
    for target in target_variables:
        print(f"\nAnalyzing {target}")
        
        model, train, test = build_sarima_model(
            data,
            target,
            'Forecasted_Smoke_Estimate',
            train_end_date='2020-12-31'
        )
        
        forecast_inc, forecast_const, smoke_inc, smoke_const, conf_int_inc = forecast_scenarios(
            model,
            train,
            future_periods,
            'Forecasted_Smoke_Estimate'
        )
        
        results[target] = {
            'forecast_increasing': forecast_inc,
            'forecast_constant': forecast_const,
            'actual_data': data[target]
        }
        
        # Plot the forecasts with confidence intervals
        plot_forecasts(data, target, forecast_inc, forecast_const, conf_int_inc, '2020-12-31')

    
    print("\nImpact Analysis: ")
    for target in target_variables:
        inc_forecast = results[target]['forecast_increasing']
        const_forecast = results[target]['forecast_constant']
        
        avg_impact = ((inc_forecast - const_forecast) / const_forecast * 100).mean()
        
        print(f"\n{target}:")
        print(f"Average predicted impact: {avg_impact:.2f}%")
        print(f"Maximum predicted impact: {((inc_forecast - const_forecast) / const_forecast * 100).max():.2f}%")

    return results

if __name__ == "__main__":
    results = main()
# Out:
# Analyzing monthly_market_hotness_ranking
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency M will be used.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency M will be used.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# Impact Analysis:
#
# monthly_market_hotness_ranking:
# Average predicted impact: -51.34%
# Maximum predicted impact: -0.20%

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt

def prepare_monthly_data(df):
    df = df.copy()
    df['DATE'] = pd.to_datetime(df['DATE'])
    df.set_index('DATE', inplace=True)
    
    for column in df.columns:
        if df[column].isnull().any():
            df[column] = df[column].interpolate(method='linear')
            df[column] = df[column].fillna(method='ffill').fillna(method='bfill')
    
    return df

def split_wildfire_nonwildfire(df):
    # Assuming wildfire months are June through September
    wildfire_months = df[df.index.month.isin([6, 7, 8, 9])]
    nonwildfire_months = df[~df.index.month.isin([6, 7, 8, 9])]
    return wildfire_months, nonwildfire_months

def build_sarima_model(data, target_col, smoke_col, train_end_date='2020-12-31'):
    train = data[data.index <= train_end_date]
    test = data[data.index > train_end_date]
    
    model = SARIMAX(train[target_col],
                    exog=train[smoke_col],
                    order=(2, 1, 2),
                    seasonal_order=(1, 1, 1, 12))
    
    results = model.fit()
    
    return results, train, test

def forecast_scenarios(model, train_data, future_periods, smoke_col):
    last_smoke = train_data[smoke_col].iloc[-1]
    smoke_trend = (train_data[smoke_col].iloc[-1] - train_data[smoke_col].iloc[0]) / len(train_data)
    
    future_smoke_increasing = np.array([last_smoke + smoke_trend * i for i in range(1, future_periods + 1)])
    future_smoke_constant = np.array([last_smoke] * future_periods)
    
    forecast_increasing = model.forecast(future_periods, exog=future_smoke_increasing)
    forecast_constant = model.forecast(future_periods, exog=future_smoke_constant)
    
    return forecast_increasing, forecast_constant, future_smoke_increasing, future_smoke_constant

def plot_forecasts(data, target_col, forecast_inc, forecast_const, train_end_date, title_suffix):
    plt.figure(figsize=(12, 6))
    
    plt.plot(data.index[data.index <= train_end_date], 
             data[target_col][data.index <= train_end_date], 
             'b-', label='Historical Data')
    
    future_dates = pd.date_range(start=pd.to_datetime(train_end_date) + pd.Timedelta(days=1), 
                                periods=len(forecast_inc), 
                                freq='M')
    
    plt.plot(future_dates, forecast_inc, 'r--', label='Forecast (Increasing Smoke)')
    plt.plot(future_dates, forecast_const, 'g--', label='Forecast (Constant Smoke)')
    
    plt.title(f'Forecasts for {target_col} - {title_suffix}')
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True)
    plt.show()

def main():
    # Prepare data
    data = prepare_monthly_data(monthly_df)
    
    # Split into wildfire and non-wildfire months
    wildfire_data, nonwildfire_data = split_wildfire_nonwildfire(data)
    
    target_variables = ['monthly_market_hotness_ranking']
    
    future_periods = 12 * 30  # Monthly data from 2021 to 2050
    
    results = {}
    
    for dataset, dataset_name in [(wildfire_data, "Wildfire Months"), (nonwildfire_data, "Non-Wildfire Months")]:
        results[dataset_name] = {}
        
        for target in target_variables:
            print(f"\nAnalyzing {target} for {dataset_name}")
            
            model, train, test = build_sarima_model(
                dataset,
                target,
                'Forecasted_Smoke_Estimate',
                train_end_date='2020-12-31'
            )
            
            forecast_inc, forecast_const, smoke_inc, smoke_const = forecast_scenarios(
                model,
                train,
                future_periods,
                'Forecasted_Smoke_Estimate'
            )
            
            results[dataset_name][target] = {
                'forecast_increasing': forecast_inc,
                'forecast_constant': forecast_const,
                'actual_data': dataset[target]
            }
            
            plot_forecasts(dataset, target, forecast_inc, forecast_const, '2020-12-31', dataset_name)
        
        print(f"\nImpact Analysis for {dataset_name}:")
        for target in target_variables:
            inc_forecast = results[dataset_name][target]['forecast_increasing']
            const_forecast = results[dataset_name][target]['forecast_constant']
            
            avg_impact = ((inc_forecast - const_forecast) / const_forecast * 100).mean()
            
            print(f"\n{target}:")
            print(f"Average predicted impact: {avg_impact:.2f}%")
            print(f"Maximum predicted impact: {((inc_forecast - const_forecast) / const_forecast * 100).max():.2f}%")

    return results

if __name__ == "__main__":
    results = main()
# Out:
# Analyzing monthly_market_hotness_ranking for Wildfire Months
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
# Impact Analysis for Wildfire Months:
#
# monthly_market_hotness_ranking:
# Average predicted impact: -32.51%
# Maximum predicted impact: -0.50%
#
# Analyzing monthly_market_hotness_ranking for Non-Wildfire Months
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
# Impact Analysis for Non-Wildfire Months:
#
# monthly_market_hotness_ranking:
# Average predicted impact: -134.38%
# Maximum predicted impact: -0.39%

# %%
def forecast_scenarios(model, train_data, future_periods, smoke_col):
    last_smoke = train_data[smoke_col].iloc[-1]
    smoke_trend = (train_data[smoke_col].iloc[-1] - train_data[smoke_col].iloc[0]) / len(train_data)
    
    future_smoke_increasing = np.array([last_smoke + smoke_trend * i for i in range(1, future_periods + 1)])
    future_smoke_constant = np.array([last_smoke] * future_periods)
    
    # Forecast for increasing smoke with confidence intervals
    forecast_increasing = model.get_forecast(steps=future_periods, exog=future_smoke_increasing)
    forecast_constant = model.forecast(future_periods, exog=future_smoke_constant)
    
    # Get confidence intervals for the increasing smoke forecast
    conf_int_increasing = forecast_increasing.conf_int(alpha=0.01)  # 95% CI
    
    return forecast_increasing.predicted_mean, forecast_constant, future_smoke_increasing, future_smoke_constant, conf_int_increasing

def plot_forecasts(data, target_col, forecast_inc, forecast_const, conf_int_inc, train_end_date, title_suffix):
    plt.figure(figsize=(16, 8))
    
    # Plot historical data
    plt.plot(data.index[data.index <= train_end_date], 
             data[target_col][data.index <= train_end_date], 
             'b-', label='Historical Data')
    
    future_dates = pd.date_range(start=pd.to_datetime(train_end_date) + pd.Timedelta(days=1), 
                                periods=len(forecast_inc), 
                                freq='M')
    
    # Plot the forecasts for both increasing and constant smoke
    plt.plot(future_dates, forecast_inc, 'r--', label='Forecast (Increasing Smoke)')
    plt.plot(future_dates, forecast_const, 'g--', label='Forecast (Constant Smoke)')
    
    # Plot the confidence intervals for increasing smoke forecast
    plt.fill_between(future_dates, 
                     conf_int_inc.iloc[:, 0], 
                     conf_int_inc.iloc[:, 1], 
                     color='red', alpha=0.2)  # Confidence interval fill
    
    # Add titles and labels
    plt.title(f'Forecasts for {target_col} - {title_suffix}')
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True)
    plt.show()

def main():
    # Prepare data
    data = prepare_monthly_data(monthly_df)
    
    # Split into wildfire and non-wildfire months
    wildfire_data, nonwildfire_data = split_wildfire_nonwildfire(data)
    
    target_variables = ['monthly_market_hotness_ranking']
    
    future_periods = 12 * 30  # Monthly data from 2021 to 2050
    
    results = {}
    
    for dataset, dataset_name in [(wildfire_data, "Wildfire Months"), (nonwildfire_data, "Non-Wildfire Months")]:
        results[dataset_name] = {}
        
        for target in target_variables:
            print(f"\nAnalyzing {target} for {dataset_name}")
            
            model, train, test = build_sarima_model(
                dataset,
                target,
                'Forecasted_Smoke_Estimate',
                train_end_date='2020-12-31'
            )
            
            # Get forecast, confidence interval, and smoke levels
            forecast_inc, forecast_const, smoke_inc, smoke_const, conf_int_inc = forecast_scenarios(
                model,
                train,
                future_periods,
                'Forecasted_Smoke_Estimate'
            )
            
            results[dataset_name][target] = {
                'forecast_increasing': forecast_inc,
                'forecast_constant': forecast_const,
                'actual_data': dataset[target]
            }
            
            # Plot the forecasts and confidence intervals
            plot_forecasts(dataset, target, forecast_inc, forecast_const, conf_int_inc, '2020-12-31', dataset_name)
        
        print(f"\nImpact Analysis for {dataset_name}:")
        for target in target_variables:
            inc_forecast = results[dataset_name][target]['forecast_increasing']
            const_forecast = results[dataset_name][target]['forecast_constant']
            
            avg_impact = ((inc_forecast - const_forecast) / const_forecast * 100).mean()
            
            print(f"\n{target}:")
            print(f"Average predicted impact: {avg_impact:.2f}%")
            print(f"Maximum predicted impact: {((inc_forecast - const_forecast) / const_forecast * 100).max():.2f}%")

    return results

if __name__ == "__main__":
    results = main()
# Out:
# Analyzing monthly_market_hotness_ranking for Wildfire Months
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
# Impact Analysis for Wildfire Months:
#
# monthly_market_hotness_ranking:
# Average predicted impact: -32.51%
# Maximum predicted impact: -0.50%
#
# Analyzing monthly_market_hotness_ranking for Non-Wildfire Months
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navya\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
# Impact Analysis for Non-Wildfire Months:
#
# monthly_market_hotness_ranking:
# Average predicted impact: -134.38%
# Maximum predicted impact: -0.39%
